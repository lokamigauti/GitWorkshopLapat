# %% [markdown]
# ## Script para contribuição

# %%
names = ['Leo', 'Marcinha', 'Mario'] # Add your name here
print(*names[:-1], sep = ", ", end=' e ')
print(names[-1], 'chegaram aqui!')

# run the script
# Out:
# Leo, Marcinha e Mario chegaram aqui!
